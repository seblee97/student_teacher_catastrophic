# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import pandas as pd
import os
import torch

# %%
result_folder_path = "../run/results/2020-11-27-18-39-31/"

# %%
v_0_dfs = [pd.read_csv(os.path.join(result_folder_path, "v_0.0", str(i), "ode_log.csv")) for i in range(4)]
v_05_dfs = [pd.read_csv(os.path.join(result_folder_path, "v_0.5", str(i), "ode_log.csv")) for i in range(4)]
v_1_dfs = [pd.read_csv(os.path.join(result_folder_path, "v_1.0", str(i), "ode_log.csv")) for i in range(4)]

# %%
switch_errors_1_v_0 = [df.generalisation_error_1[4999] for df in v_0_dfs]
switch_errors_1_v_05 = [df.generalisation_error_1[4999] for df in v_05_dfs]
switch_errors_1_v_1 = [df.generalisation_error_1[4999] for df in v_1_dfs]

# %%
final_errors_1_v_0 = [df.generalisation_error_1[14999] for df in v_0_dfs]
final_errors_1_v_05 = [df.generalisation_error_1[14999] for df in v_05_dfs]
final_errors_1_v_1 = [df.generalisation_error_1[14999] for df in v_1_dfs]

# %%
np.mean(switch_errors_1_v_0)
# Out:
# 0.16666699583914268

# %%
np.mean(switch_errors_1_v_05)
# Out:
# 0.1666277917550475

# %%
np.mean(switch_errors_1_v_1)
# Out:
# 0.16658679863908232

# %%
switch_errors_1_v_0
# Out:
# [0.1666673724976083,
#  0.16666694764333728,
#  0.16666685836215756,
#  0.1666668048534676]

# %%
switch_errors_1_v_05
# Out:
# [0.16633579986924776,
#  0.16687021083483913,
#  0.1664933885260317,
#  0.16681176779007134]

# %%
np.mean(final_errors_1_v_0)
# Out:
# 9.304545774398458e-05

# %%
np.mean(final_errors_1_v_05)
# Out:
# 6.928214311390651e-05

# %%
np.mean(final_errors_1_v_1)
# Out:
# 1.3435127961433993e-05

# %%
result_folder_path = "../run/results/multi_seed_feature_sim_three_points/"

# %%
v_0_dfs = [pd.read_csv(os.path.join(result_folder_path, "v_0.0", str(i), "ode_log.csv")) for i in range(4)]
v_05_dfs = [pd.read_csv(os.path.join(result_folder_path, "v_0.5", str(i), "ode_log.csv")) for i in range(4)]
v_1_dfs = [pd.read_csv(os.path.join(result_folder_path, "v_1.0", str(i), "ode_log.csv")) for i in range(4)]

# %%
v_0_dfs[0].generalisation_error_0[14999] - v_0_dfs[0].generalisation_error_0[4999]
# Out:
# 0.0009497362628354544

# %%
v_0_dfs[1].generalisation_error_0[14999] - v_0_dfs[1].generalisation_error_0[4999]
# Out:
# 0.005821384159718396

# %%
v_0_dfs[2].generalisation_error_0[14999] - v_0_dfs[2].generalisation_error_0[4999]
# Out:
# 0.004139326366331297

# %%
v_0_dfs[3].generalisation_error_0[14999] - v_0_dfs[3].generalisation_error_0[4999]
# Out:
# 0.04403410931718085

# %%
v_1_dfs[0].generalisation_error_0[14999] - v_1_dfs[0].generalisation_error_0[4999]
# Out:
# 0.0010370710904580305

# %%
v_1_dfs[1].generalisation_error_0[14999] - v_1_dfs[1].generalisation_error_0[4999]
# Out:
# 0.0026176185810188185

# %%
v_1_dfs[2].generalisation_error_0[14999] - v_1_dfs[2].generalisation_error_0[4999]
# Out:
# 0.0022384232171990255

# %%
v_1_dfs[3].generalisation_error_0[14999] - v_1_dfs[3].generalisation_error_0[4999]
# Out:
# 0.003784054451908797

# %%
def forgetting_rate(df, switch_step):
    diffs = [df.generalisation_error_0[switch_step + i + 1] - df.generalisation_error_0[switch_step + i] for i in range(100)]
    return np.mean(diffs)

# %%
np.mean([forgetting_rate(v, 4999) for v in v_0_dfs])
# Out:
# 3.258222188551971e-11

# %%
np.mean([forgetting_rate(v, 4999) for v in v_05_dfs])
# Out:
# 2.3107683471880464e-06

# %%
np.mean([forgetting_rate(v, 4999) for v in v_1_dfs])
# Out:
# 2.3011945966167585e-06

# %%
a = np.random.random((5,5))
b = np.random.random((5,5))

# %%
a
# Out:
# array([[0.69736747, 0.16516276, 0.90279216, 0.49593215, 0.56302605],
#        [0.88354326, 0.06976316, 0.35677661, 0.85066344, 0.86333938],
#        [0.52204429, 0.63714375, 0.51594732, 0.4218861 , 0.39733109],
#        [0.21504044, 0.67171875, 0.9454689 , 0.51904856, 0.59064479],
#        [0.25327333, 0.82884417, 0.23711358, 0.52899385, 0.06136453]])

# %%
b
# Out:
# array([[0.33728616, 0.40180778, 0.9073368 , 0.21273702, 0.51619511],
#        [0.37186429, 0.8257682 , 0.98940679, 0.19149318, 0.01966356],
#        [0.04256815, 0.74923448, 0.61786179, 0.59022673, 0.54047229],
#        [0.72736471, 0.2328368 , 0.37767577, 0.23747439, 0.1637848 ],
#        [0.20858173, 0.39168356, 0.91600876, 0.51198857, 0.51949205]])

# %%
a = {}

# %%
a[5] = 6

# %%
a
# Out:
# {5: 6}

# %%
a[4] = {4: 8, 5: 6}

# %%
a.items()
# Out:
# dict_items([(4, {4: 8, 5: 6})])

# %%
b,c = a.items()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-328690ff8074> in <module>
# ----> 1 b,c = a.items()
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
b
# Out:
# (5, 6)

# %%
# Out:
# (4, {4: 8})

# %%
b, c = a.keys(), a.values()

# %%
list(b)
# Out:
# [5, 4]

# %%
list(c)
# Out:
# [6, {4: 8}]

# %%
import numpy as np

# %%
a = np.zeros((5,5))

# %%
type(a.shape)
# Out:
# tuple

# %%
(5,) + a.shape
# Out:
# (5, 5, 5)

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
results_folder = "/Users/sebastianlee/Dropbox/Documents/Research/Projects/catastrophic/run/results/2021-01-25-18-31-05"

# %%
forgets = {}
transfers = {}

error_0 = {}
error_1 = {}

for i in np.linspace(0, 1, 25):
    i_df = pd.read_csv(os.path.join(results_folder, f"v_{i}", "0", "ode_log.csv"))
    switch_error_0 = i_df["log_generalisation_error_0"].iloc[20000]
    switch_error_1 = i_df["log_generalisation_error_1"].iloc[20000]
    final_error_0 = i_df["log_generalisation_error_0"].iloc[100000]
    final_error_1 = i_df["log_generalisation_error_1"].iloc[100000]
    final_forgetting = final_error_0 - switch_error_0
    final_transfer = switch_error_1 - final_error_1
    forgets[i] = final_forgetting
    transfers[i] = final_transfer
    error_0[i] = np.array(i_df["log_generalisation_error_0"])
    error_1[i] = np.array(i_df["log_generalisation_error_1"])

# %%
color_map = cm.get_cmap("viridis")

fig = plt.figure()
for i, (overlap, err) in enumerate(error_0.items()):
    plt.plot(10*np.arange(len(err)), err, color=color_map(i/len(error_0)))
plt.legend()
fig.show()
fig.savefig("long_time.pdf", dpi=100)
# Out:
# No handles with labels found to put in legend.
# <ipython-input-37-aa1559aa4d7e>:7: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
color_map = cm.get_cmap("plasma")

fig = plt.figure()
for i, (overlap, err) in enumerate(error_1.items()):
    plt.plot(range(len(err)), err, color=color_map(i/len(error_1)))
plt.legend()
fig.show()
fig.savefig("long_time_transfer.pdf", dpi=100)
# Out:
# No handles with labels found to put in legend.
# <ipython-input-38-69e76ce3520b>:7: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = plt.figure()
plt.plot(forgets.keys(), forgets.values())
fig.show()
# Out:
# <ipython-input-31-9933a0be235e>:3: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = plt.figure()
plt.plot(transfers.keys(), transfers.values())
fig.show()
# Out:
# <ipython-input-26-7bb6ca834c11>:3: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
results_folder = "/Users/sebastianlee/Dropbox/Documents/Research/Projects/catastrophic/run/results/2021-01-27-13-38-01/"

# %%
forgets = {}
transfers = {}

error_0 = {}
error_1 = {}

for i in np.linspace(0, 1, 15):
    i_df = pd.read_csv(os.path.join(results_folder, f"v_{i}", "0", "network_log.csv"))
    switch_error_0 = np.array(i_df["log_generalisation_error_0"])[2500]
    switch_error_1 = np.array(i_df["log_generalisation_error_1"])[2500]
    final_error_0 = np.array(i_df["log_generalisation_error_0"])[-1]
    final_error_1 = np.array(i_df["log_generalisation_error_1"])[-1]
    final_forgetting = final_error_0 - switch_error_0
    final_transfer = switch_error_1 - final_error_1
    forgets[i] = final_forgetting
    transfers[i] = final_transfer
    error_0[i] = np.array(i_df["log_generalisation_error_0"])
    error_1[i] = np.array(i_df["log_generalisation_error_1"])

# %%
color_map = cm.get_cmap("viridis")

fig = plt.figure()
for i, (overlap, err) in enumerate(error_0.items()):
    plt.plot(100*np.arange(len(err)), err, color=color_map(i/len(error_0)))
# for i, (overlap, err) in enumerate(error_0_.items()):
#     plt.plot(np.arange(len(err)), err, color=color_map(i/len(error_0_)), linestyle="dashed")
plt.legend()
fig.show()
# fig.savefig("long_time.pdf", dpi=100)
# Out:
# No handles with labels found to put in legend.
# <ipython-input-46-24340976219f>:9: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
color_map = cm.get_cmap("viridis")

fig = plt.figure()
for i, (overlap, err) in enumerate(error_0.items()):
    plt.plot(10*np.arange(len(err)), err, color=color_map(i/len(error_0)))
plt.legend()
fig.show()
# fig.savefig("long_time.pdf", dpi=100)
# Out:
# No handles with labels found to put in legend.
# <ipython-input-28-9f506b83d707>:7: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
len(error_0[1.0])
# Out:
# 182000

# %%
color_map = cm.get_cmap("plasma")

fig = plt.figure()
for i, (overlap, err) in enumerate(error_1.items()):
    plt.plot(10*np.arange(len(err)), err, color=color_map(i/len(error_0)))
plt.legend()
fig.show()
fig.savefig("long_time.pdf", dpi=100)
# Out:
# No handles with labels found to put in legend.
# <ipython-input-11-aac5cef4cadf>:7: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
results_folder = "/Users/sebastianlee/Dropbox/Documents/Research/Projects/catastrophic/run/results/2021-01-30-12-54-05/"
results_folder = "/Users/sebastianlee/Dropbox/Documents/Research/Projects/catastrophic/run/results/2021-01-30-16-18-53/"
results_folder = "/Users/sebastianlee/Dropbox/Documents/Research/Projects/catastrophic/run/results/2021-01-30-19-32-30/"
results_folder = "/Users/sebastianlee/Dropbox/Documents/Research/Projects/catastrophic/run/results/2021-01-31-11-02-09/"

# %%
def extract(folder, i_range):
    error_0 = {}
    error_1 = {}

    for i in i_range:
#         i = i / 100

        try:
            i_df = pd.read_csv(os.path.join(results_folder, f"v_{i}", "0", "ode_log.csv"))
            switch_error_0 = np.array(i_df["log_generalisation_error_0"])[5000]
            switch_error_1 = np.array(i_df["log_generalisation_error_1"])[5000]
            final_error_0 = np.array(i_df["log_generalisation_error_0"])[-1]
            final_error_1 = np.array(i_df["log_generalisation_error_1"])[-1]
            final_forgetting = final_error_0 - switch_error_0
            final_transfer = switch_error_1 - final_error_1
            forgets[i] = final_forgetting
            transfers[i] = final_transfer
            error_0[i] = np.array(i_df["log_generalisation_error_0"])
            error_1[i] = np.array(i_df["log_generalisation_error_1"])
        except:
            print(i)

    error_0_ = {}
    error_1_ = {}

#     for i in i_range:
# #         i = i / 100
#         i_df = pd.read_csv(os.path.join(results_folder, f"v_{i}", "0", "network_log.csv"))
#         switch_error_0 = np.array(i_df["log_generalisation_error_0"])[5000]
#         switch_error_1 = np.array(i_df["log_generalisation_error_1"])[5000]
#         final_error_0 = np.array(i_df["log_generalisation_error_0"])[-1]
#         final_error_1 = np.array(i_df["log_generalisation_error_1"])[-1]
#         final_forgetting = final_error_0 - switch_error_0
#         final_transfer = switch_error_1 - final_error_1
#         forgets[i] = final_forgetting
#         transfers[i] = final_transfer
#         error_0_[i] = np.array(i_df["log_generalisation_error_0"])
#         error_1_[i] = np.array(i_df["log_generalisation_error_1"])
        
    return error_0, error_1, error_0_, error_1_

# %%
full_range_ode = extract(results_folder, np.linspace(0, 1, 401))
# Out:
# 0.8425
# 0.845
# 0.8475
# 0.85
# 0.8525
# 0.855
# 0.8575
# 0.86
# 0.8625
# 0.865
# 0.8675
# 0.87
# 0.8725
# 0.875
# 0.8775000000000001
# 0.88
# 0.8825000000000001
# 0.885
# 0.8875000000000001
# 0.89
# 0.8925000000000001
# 0.895
# 0.8975
# 0.9
# 0.9025
# 0.905
# 0.9075
# 0.91
# 0.9125
# 0.915
# 0.9175
# 0.92
# 0.9225
# 0.925
# 0.9275
# 0.93
# 0.9325
# 0.935
# 0.9375
# 0.9400000000000001
# 0.9425
# 0.9450000000000001
# 0.9475
# 0.9500000000000001
# 0.9525
# 0.9550000000000001
# 0.9575
# 0.96
# 0.9625
# 0.965
# 0.9675
# 0.97
# 0.9725
# 0.975
# 0.9775
# 0.98
# 0.9825
# 0.985
# 0.9875
# 0.99
# 0.9925
# 0.995
# 0.9975
# 1.0

# %%
# Out:
# array([0.    , 0.0025, 0.005 , 0.0075, 0.01  , 0.0125, 0.015 , 0.0175,
#        0.02  , 0.0225, 0.025 , 0.0275, 0.03  , 0.0325, 0.035 , 0.0375,
#        0.04  , 0.0425, 0.045 , 0.0475, 0.05  , 0.0525, 0.055 , 0.0575,
#        0.06  , 0.0625, 0.065 , 0.0675, 0.07  , 0.0725, 0.075 , 0.0775,
#        0.08  , 0.0825, 0.085 , 0.0875, 0.09  , 0.0925, 0.095 , 0.0975,
#        0.1   , 0.1025, 0.105 , 0.1075, 0.11  , 0.1125, 0.115 , 0.1175,
#        0.12  , 0.1225, 0.125 , 0.1275, 0.13  , 0.1325, 0.135 , 0.1375,
#        0.14  , 0.1425, 0.145 , 0.1475, 0.15  , 0.1525, 0.155 , 0.1575,
#        0.16  , 0.1625, 0.165 , 0.1675, 0.17  , 0.1725, 0.175 , 0.1775,
#        0.18  , 0.1825, 0.185 , 0.1875, 0.19  , 0.1925, 0.195 , 0.1975,
#        0.2   , 0.2025, 0.205 , 0.2075, 0.21  , 0.2125, 0.215 , 0.2175,
#        0.22  , 0.2225, 0.225 , 0.2275, 0.23  , 0.2325, 0.235 , 0.2375,
#        0.24  , 0.2425, 0.245 , 0.2475, 0.25  , 0.2525, 0.255 , 0.2575,
#        0.26  , 0.2625, 0.265 , 0.2675, 0.27  , 0.2725, 0.275 , 0.2775,
#        0.28  , 0.2825, 0.285 , 0.2875, 0.29  , 0.2925, 0.295 , 0.2975,
#        0.3   , 0.3025, 0.305 , 0.3075, 0.31  , 0.3125, 0.315 , 0.3175,
#        0.32  , 0.3225, 0.325 , 0.3275, 0.33  , 0.3325, 0.335 , 0.3375,
#        0.34  , 0.3425, 0.345 , 0.3475, 0.35  , 0.3525, 0.355 , 0.3575,
#        0.36  , 0.3625, 0.365 , 0.3675, 0.37  , 0.3725, 0.375 , 0.3775,
#        0.38  , 0.3825, 0.385 , 0.3875, 0.39  , 0.3925, 0.395 , 0.3975,
#        0.4   , 0.4025, 0.405 , 0.4075, 0.41  , 0.4125, 0.415 , 0.4175,
#        0.42  , 0.4225, 0.425 , 0.4275, 0.43  , 0.4325, 0.435 , 0.4375,
#        0.44  , 0.4425, 0.445 , 0.4475, 0.45  , 0.4525, 0.455 , 0.4575,
#        0.46  , 0.4625, 0.465 , 0.4675, 0.47  , 0.4725, 0.475 , 0.4775,
#        0.48  , 0.4825, 0.485 , 0.4875, 0.49  , 0.4925, 0.495 , 0.4975,
#        0.5   , 0.5025, 0.505 , 0.5075, 0.51  , 0.5125, 0.515 , 0.5175,
#        0.52  , 0.5225, 0.525 , 0.5275, 0.53  , 0.5325, 0.535 , 0.5375,
#        0.54  , 0.5425, 0.545 , 0.5475, 0.55  , 0.5525, 0.555 , 0.5575,
#        0.56  , 0.5625, 0.565 , 0.5675, 0.57  , 0.5725, 0.575 , 0.5775,
#        0.58  , 0.5825, 0.585 , 0.5875, 0.59  , 0.5925, 0.595 , 0.5975,
#        0.6   , 0.6025, 0.605 , 0.6075, 0.61  , 0.6125, 0.615 , 0.6175,
#        0.62  , 0.6225, 0.625 , 0.6275, 0.63  , 0.6325, 0.635 , 0.6375,
#        0.64  , 0.6425, 0.645 , 0.6475, 0.65  , 0.6525, 0.655 , 0.6575,
#        0.66  , 0.6625, 0.665 , 0.6675, 0.67  , 0.6725, 0.675 , 0.6775,
#        0.68  , 0.6825, 0.685 , 0.6875, 0.69  , 0.6925, 0.695 , 0.6975,
#        0.7   , 0.7025, 0.705 , 0.7075, 0.71  , 0.7125, 0.715 , 0.7175,
#        0.72  , 0.7225, 0.725 , 0.7275, 0.73  , 0.7325, 0.735 , 0.7375,
#        0.74  , 0.7425, 0.745 , 0.7475, 0.75  , 0.7525, 0.755 , 0.7575,
#        0.76  , 0.7625, 0.765 , 0.7675, 0.77  , 0.7725, 0.775 , 0.7775,
#        0.78  , 0.7825, 0.785 , 0.7875, 0.79  , 0.7925, 0.795 , 0.7975,
#        0.8   , 0.8025, 0.805 , 0.8075, 0.81  , 0.8125, 0.815 , 0.8175,
#        0.82  , 0.8225, 0.825 , 0.8275, 0.83  , 0.8325, 0.835 , 0.8375,
#        0.84  , 0.8425, 0.845 , 0.8475, 0.85  , 0.8525, 0.855 , 0.8575,
#        0.86  , 0.8625, 0.865 , 0.8675, 0.87  , 0.8725, 0.875 , 0.8775,
#        0.88  , 0.8825, 0.885 , 0.8875, 0.89  , 0.8925, 0.895 , 0.8975,
#        0.9   , 0.9025, 0.905 , 0.9075, 0.91  , 0.9125, 0.915 , 0.9175,
#        0.92  , 0.9225, 0.925 , 0.9275, 0.93  , 0.9325, 0.935 , 0.9375,
#        0.94  , 0.9425, 0.945 , 0.9475, 0.95  , 0.9525, 0.955 , 0.9575,
#        0.96  , 0.9625, 0.965 , 0.9675, 0.97  , 0.9725, 0.975 , 0.9775,
#        0.98  , 0.9825, 0.985 , 0.9875, 0.99  , 0.9925, 0.995 , 0.9975,
#        1.    ])

# %%
forgets = {}
transfers = {}

error_0 = {}
error_1 = {}

for i in range(0, 102, 2):
    i = i / 100
    i_df = pd.read_csv(os.path.join(results_folder, f"v_{i}", "0", "ode_log.csv"))
    switch_error_0 = np.array(i_df["log_generalisation_error_0"])[5000]
    switch_error_1 = np.array(i_df["log_generalisation_error_1"])[5000]
    final_error_0 = np.array(i_df["log_generalisation_error_0"])[-1]
    final_error_1 = np.array(i_df["log_generalisation_error_1"])[-1]
    final_forgetting = final_error_0 - switch_error_0
    final_transfer = switch_error_1 - final_error_1
    forgets[i] = final_forgetting
    transfers[i] = final_transfer
    error_0[i] = np.array(i_df["log_generalisation_error_0"])
    error_1[i] = np.array(i_df["log_generalisation_error_1"])
    
error_0_ = {}
error_1_ = {}
    
for i in range(0, 102, 2):
    i = i / 100
    i_df = pd.read_csv(os.path.join(results_folder, f"v_{i}", "0", "network_log.csv"))
    switch_error_0 = np.array(i_df["log_generalisation_error_0"])[5000]
    switch_error_1 = np.array(i_df["log_generalisation_error_1"])[5000]
    final_error_0 = np.array(i_df["log_generalisation_error_0"])[-1]
    final_error_1 = np.array(i_df["log_generalisation_error_1"])[-1]
    final_forgetting = final_error_0 - switch_error_0
    final_transfer = switch_error_1 - final_error_1
    forgets[i] = final_forgetting
    transfers[i] = final_transfer
    error_0_[i] = np.array(i_df["log_generalisation_error_0"])
    error_1_[i] = np.array(i_df["log_generalisation_error_1"])

# %%
fig = plt.figure()
ode_df = pd.read_csv(os.path.join(results_folder, "v_0.0", "0", "ode_log.csv"))
network_df = pd.read_csv(os.path.join(results_folder, "v_0.0", "0", "network_log.csv"))
ode_0 = np.array(ode_df.log_generalisation_error_0)
ode_1 = np.array(ode_df.log_generalisation_error_1)
network_0 = np.array(network_df.log_generalisation_error_0)
network_1 = np.array(network_df.log_generalisation_error_1)
plt.plot(range(len(ode_0)), ode_0)
plt.scatter(range(len(network_0)), network_0)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-54-959413cf0fd9> in <module>
#       1 fig = plt.figure()
# ----> 2 ode_df = pd.read_csv(os.path.join(results_folder, "v_0.0", "0", "ode_log.csv"))
#       3 network_df = pd.read_csv(os.path.join(results_folder, "v_0.0", "0", "network_log.csv"))
#       4 ode_0 = np.array(ode_df.log_generalisation_error_0)
#       5 ode_1 = np.array(ode_df.log_generalisation_error_1)
#
# ~/envs/cata/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# ~/envs/cata/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# ~/envs/cata/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# ~/envs/cata/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# ~/envs/cata/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/sebastianlee/Dropbox/Documents/Research/Projects/catastrophic/run/results/2021-01-30-16-18-53/v_0.0/0/ode_log.csv'

# %%
plt.plot(range(len(error_0[1.0])), error_0[1.0])

# %%
error_0[0.0]
# Out:
# array([-0.77815129, -0.7781513 , -0.7781513 , ..., -2.10506628,
#        -2.10505905, -2.10505182])

# %%
color_map = cm.get_cmap("viridis")

N = 30000
M = 100
switch = 10000

fig = plt.figure(figsize=(20, 12))

# plt.plot(np.arange(len(error_0[0.0][:switch])), error_0[0.0][:switch], color='k', alpha=0.4, linewidth=3)
for i, (overlap, err) in enumerate(error_0.items()):
#     if i in [20]:
    plt.plot(np.arange(len(err[:N])), err[:N], color=color_map(i/len(error_0)), alpha=0.8, linewidth=5)
    
# for i, (overlap, err) in enumerate(error_0_.items()):
#     if i in [1, 100]:
#         plt.scatter(np.arange(switch, len(err[:N]))[0::M], err[switch:N][0::M], color=color_map(i/len(error_0_)), s=100, marker="+")

plt.legend()
plt.xlim(0, N)
plt.ylim(-4.5, -0.5)
plt.minorticks_on()
plt.grid(b=True, which='major', color='r', linestyle='-', alpha=0.2)
plt.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)
plt.tick_params(
            axis='both',         # changes apply to the x-axis
            which='both',      # both major and minor ticks are affected
            bottom=False,      # ticks along the bottom edge are off
            top=False,         # ticks along the top edge are off
            labelbottom=False, # labels along the bottom edge are off
            left=False,
            labelleft=False
        ) 
fig.show()
fig.savefig("long_time_forgetting_no_crosses.pdf", dpi=100, bbox_inches='tight', pad_inches=0)
# Out:
# No handles with labels found to put in legend.
# <ipython-input-118-004370be57d7>:33: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
color_map = cm.get_cmap("plasma")

N = 30000
M = 100
switch = 10000
factor = 1

fig = plt.figure(figsize=(20, 12))

plt.plot(np.arange(len(error_1[0.0][:switch])), error_1[0.0][:switch], color='k', alpha=0.4, linewidth=5)
for i, (overlap, err) in enumerate(error_1.items()):
#     if i in [0, 1]:
    plt.plot(np.arange(switch, len(err[:N])), err[switch:N], color=color_map(i/len(error_1)), alpha=0.8, linewidth=5)
    
for i, (overlap, err) in enumerate(error_1.items()):
    if i in [0, 1]:
        plt.scatter(np.arange(switch//factor, len(error_1_[overlap][:N//factor]))[0::M], error_1_[overlap][switch//factor:N//factor][0::M], color=color_map(i/len(error_1_)), s=100, marker="+")

plt.legend()
plt.xlim(0, N)
plt.ylim(-11, 0)
plt.minorticks_on()
plt.grid(b=True, which='major', color='r', linestyle='-', alpha=0.2)
plt.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)
plt.tick_params(
            axis='both',         # changes apply to the x-axis
            which='both',      # both major and minor ticks are affected
            bottom=False,      # ticks along the bottom edge are off
            top=False,         # ticks along the top edge are off
            labelbottom=False, # labels along the bottom edge are off
            left=False,
            labelleft=False
        ) 
fig.show()
fig.savefig("long_time_transfer_crosses.pdf", dpi=100, bbox_inches='tight', pad_inches=0)
# Out:
# No handles with labels found to put in legend.
# <ipython-input-117-7ffed5487051>:34: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
color_map = cm.get_cmap("viridis")

def cross_section_plot(interval):
    forgettings = {}
    fig = plt.figure()
    for i, (overlap, err) in enumerate(error_0.items()):
        switch_error = err[switch]
        interval_error = err[interval]
        forgetting = interval_error - switch_error
        forgettings[overlap] = forgetting
        plt.scatter(overlap, forgetting, color=color_map(i/len(error_0)), s=100)
    for i, (overlap, err) in enumerate(error_0_.items()):
        switch_error = err[switch]
        interval_error = err[interval]
        forgetting = interval_error - switch_error
        forgettings[overlap] = forgetting
        plt.scatter(overlap, forgetting, color=color_map(i/len(error_0)), marker='+')
    plt.minorticks_on()
    plt.grid(b=True, which='major', color='r', linestyle='-', alpha=0.2)
    plt.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)
    plt.tick_params(
                axis='both',         # changes apply to the x-axis
                which='both',      # both major and minor ticks are affected
                bottom=False,      # ticks along the bottom edge are off
                top=False,         # ticks along the top edge are off
                labelbottom=False, # labels along the bottom edge are off
                left=False,
                labelleft=False
            )
    plt.xlim(0, 1)
#     plt.ylim(0, 1)
    fig.show()
    fig.savefig(f"forgetting_cross_section_{interval - switch}_crosses.pdf", dpi=100, bbox_inches='tight', pad_inches=0)

# %%
cross_section_plot(23000)
# Out:
# <ipython-input-98-f0be80c688e7>:32: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = plt.figure()
plt.plot(np.arange(len(ode_df.log_generalisation_error_1)), np.array(ode_df.log_generalisation_error_1))
plt.plot(100 * np.arange(len(network_df.log_generalisation_error_1)), np.array(network_df.log_generalisation_error_1), linestyle="dashed")
fig.show()
# Out:
# <ipython-input-196-1d3ca2a670a9>:4: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
len(ode_df)
# Out:
# 270000

# %%
len(network_df)
# Out:
# 40000
