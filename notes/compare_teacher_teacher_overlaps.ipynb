# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("../experiments/results/2020-08-08-18-56-58/ode_logs.csv")
df2 = pd.read_csv("../experiments/results/2020-08-08-18-58-12/ode_logs.csv")

# %%
df1.head()
# Out:
#            Q_00          Q_01          Q_10      Q_11     Q_00_diff  \
# 0  9.343384e-07 -5.715264e-08 -5.715264e-08  0.000001  0.000000e+00
# 1  9.343345e-07 -5.715082e-08 -5.715082e-08  0.000001 -3.950004e-12
# 2  9.343305e-07 -5.714904e-08 -5.714904e-08  0.000001 -3.918012e-12
# 3  9.343267e-07 -5.714730e-08 -5.714730e-08  0.000001 -3.886029e-12
# 4  9.343228e-07 -5.714560e-08 -5.714560e-08  0.000001 -3.854055e-12
#
#       Q_01_diff     Q_10_diff     Q_11_diff      R_00      R_10  ...  \
# 0  0.000000e+00  0.000000e+00  0.000000e+00 -0.000022  0.000002  ...
# 1  1.823588e-12  1.823588e-12  2.132964e-12 -0.000022  0.000002  ...
# 2  1.781475e-12  1.781475e-12  2.189127e-12 -0.000022  0.000002  ...
# 3  1.739367e-12  1.739367e-12  2.245292e-12 -0.000022  0.000002  ...
# 4  1.697265e-12  1.697265e-12  2.301458e-12 -0.000022  0.000002  ...
#
#    h2_0_diff  h2_1_diff  error_linear_1  error_linear_1_diff  error_linear_2  \
# ...

# %%
df2.head()
# Out:
#            Q_00          Q_01          Q_10      Q_11     Q_00_diff  \
# 0  9.343384e-07 -5.715264e-08 -5.715264e-08  0.000001  0.000000e+00
# 1  9.343345e-07 -5.715082e-08 -5.715082e-08  0.000001 -3.950004e-12
# 2  9.343305e-07 -5.714904e-08 -5.714904e-08  0.000001 -3.918012e-12
# 3  9.343267e-07 -5.714730e-08 -5.714730e-08  0.000001 -3.886029e-12
# 4  9.343228e-07 -5.714560e-08 -5.714560e-08  0.000001 -3.854055e-12
#
#       Q_01_diff     Q_10_diff     Q_11_diff      R_00      R_10  ...  \
# 0  0.000000e+00  0.000000e+00  0.000000e+00 -0.000022  0.000002  ...
# 1  1.823588e-12  1.823588e-12  2.132964e-12 -0.000022  0.000002  ...
# 2  1.781475e-12  1.781475e-12  2.189127e-12 -0.000022  0.000002  ...
# 3  1.739367e-12  1.739367e-12  2.245292e-12 -0.000022  0.000002  ...
# 4  1.697265e-12  1.697265e-12  2.301458e-12 -0.000022  0.000002  ...
#
#    h2_0_diff  h2_1_diff  error_linear_1  error_linear_1_diff  error_linear_2  \
# ...

# %%
fig = plt.figure()
df1['U_00'].plot()
df2['U_00'].plot()
fig.show()
# Out:
# /Users/sebastianlee/Envs/cata/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   after removing the cwd from sys.path.

# %%
fig = plt.figure()
df1['error_linear_2'].plot()
df2['error_linear_2'].plot()
fig.show()
# Out:
# /Users/sebastianlee/Envs/cata/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   after removing the cwd from sys.path.

# %%
# dfs = [pd.read_csv(f"../experiments/results/2020-08-08-20-17-01/{i}/ode_logs.csv") for i in range(7)]
# dfs = [pd.read_csv(f"../experiments/results/2020-08-08-21-14-18/3/ode_logs.csv")] \
# + [pd.read_csv(f"../experiments/results/2020-08-08-21-14-19/{i}/ode_logs.csv") for i in [0, 1, 2, 4, 5, 6, 7]]
# dfs = [pd.read_csv(f"../experiments/results/2020-08-08-22-08-13/{i}/ode_logs.csv") for i in range(7)]
dfs = [pd.read_csv(f"../experiments/results/2020-08-08-23-16-20/{i}/ode_logs.csv") for i in range(3)]

# %%
fig = plt.figure(figsize=(25,16))
dfs[0]["error_log_1"].plot()
for df in dfs:
    df["error_log_2"].plot()
fig.show()
# Out:
# /Users/sebastianlee/Envs/cata/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   """

# %%
dfs[0]["U_10"]
# Out:
# 0        0.000003
# 1        0.000003
# 2        0.000003
# 3        0.000002
# 4        0.000002
#            ...
# 63696   -0.899307
# 63697   -0.899308
# 63698   -0.899310
# 63699   -0.899311
# 63700   -0.899313
# Name: U_10, Length: 63701, dtype: float64

# %%
dfs[1]["U_10"]
# Out:
# 0        1.260596e-06
# 1        1.153368e-06
# 2        1.046140e-06
# 3        9.389128e-07
# 4        8.316856e-07
#              ...
# 63696   -8.993082e-01
# 63697   -8.993098e-01
# 63698   -8.993113e-01
# 63699   -8.993129e-01
# 63700   -8.993144e-01
# Name: U_10, Length: 63701, dtype: float64
