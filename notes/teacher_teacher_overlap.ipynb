# %%
# %load_ext autoreload
# %autoreload 2

# %%
from matplotlib import cm
import numpy as np

# %%
from post_processing import teacher_teacher_plotter

# %%
plotter = teacher_teacher_plotter.TeacherTeacherPlotter(folder="../../../../Users/sebastianlee/cata_results/teacher_teacher_vs_forgetting_converged_longer/", overlaps=np.linspace(0, 1, 50))

# %%
orange_color_map = cm.get_cmap("Oranges")
green_color_map = cm.get_cmap("Greens")

yellow_red_color_map = cm.get_cmap("YlOrRd")
green_blue_color_map = cm.get_cmap("GnBu")

warm_color_map = cm.get_cmap("autumn")
cold_color_map = cm.get_cmap("winter")

# %%
plotter.plot_vs_step(attributes=["error_log_1"], labels=["Error *"], color_maps=[green_blue_color_map])
# Out:
# /Users/sebastianlee/Envs/cata/lib/python3.6/site-packages/IPython/core/events.py:88: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /Users/sebastianlee/Envs/cata/lib/python3.6/site-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plotter.plot_vs_overlap(attribute="error_log_1", steps=[45002, 45000], color="#2A9D8F")

# %%
plotter.plot_vs_overlap(attribute="error_log_1", steps=[45003, 45000], color="#2A9D8F")

# %%
plotter.plot_vs_overlap(attribute="error_log_1", steps=[45010, 45000], color="#2A9D8F")

# %%
plotter.plot_vs_overlap(attribute="error_log_1", steps=[45100, 45000], color="#2A9D8F")

# %%
plotter.plot_vs_overlap(attribute="error_log_1", steps=[45200, 45000], color="#2A9D8F")

# %%
plotter.plot_vs_overlap(attribute="error_log_1", steps=[45300, 45000], color="#2A9D8F")

# %%
plotter.plot_vs_overlap(attribute="error_log_1", steps=[45400, 45000], color="#2A9D8F")

# %%
plotter.plot_vs_overlap(attribute="error_log_1", steps=[45500, 45000], color="#2A9D8F")

# %%
plotter.plot_vs_overlap(attribute="error_log_1", steps=[46000, 45000], color="#2A9D8F")

# %%
plotter.plot_vs_overlap(attribute="error_log_1", steps=[47000, 45000], color="#2A9D8F")

# %%
plotter.plot_vs_overlap(attribute="error_log_1", steps=[48000, 45000], color="#2A9D8F")

# %%
plotter.plot_vs_overlap(attribute="error_log_1", steps=[49000, 45000], color="#2A9D8F")

# %%
plotter.plot_vs_overlap(attribute="error_log_1", steps=[50000, 45000], color="#2A9D8F")

# %%
plotter.plot_vs_overlap(attribute="error_log_1", steps=[60000, 45000], color="#2A9D8F")

# %%
plotter.plot_vs_overlap(attribute="error_log_1", steps=[70000, 45000], color="#2A9D8F")

# %%
plotter.plot_vs_overlap(attribute="error_log_1", steps=[90000, 45000], color="#2A9D8F")

# %%
plotter2 = teacher_teacher_plotter.TeacherTeacherPlotter(folder="../../../../Users/sebastianlee/cata_results/teacher_teacher_vs_forgetting/", overlaps=np.linspace(0, 1, 50))

# %%
plotter2.plot_vs_step(attributes=["error_log_1"], labels=["Error *"], color_maps=[green_blue_color_map])
# Out:
# /Users/sebastianlee/Envs/cata/lib/python3.6/site-packages/IPython/core/events.py:88: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /Users/sebastianlee/Envs/cata/lib/python3.6/site-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plotter2.plot_vs_overlap(attribute="error_log_1", steps=[2501, 2500], color="#2A9D8F")

# %%
plotter2.plot_vs_overlap(attribute="error_log_1", steps=[2600, 2500], color="#2A9D8F")

# %%
plotter2.plot_vs_overlap(attribute="error_log_1", steps=[5000, 2500], color="#2A9D8F")
