# %%
import process_logs

# %%
import os
os.listdir("/Users/sebastianlee/Dropbox/Documents/Work/Research/catastrophic/experiments/results/relu_results/trial")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-c86fa0a3289d> in <module>
#       1 import os
# ----> 2 os.listdir("/Users/sebastianlee/Dropbox/Documents/Work/Research/catastrophic/experiments/results/relu_results/trial")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/sebastianlee/Dropbox/Documents/Work/Research/catastrophic/experiments/results/relu_results/trial'

# %%
# test_dir = "/Users/sebastianlee/Dropbox/Documents/Work/Research/catastrophic/experiments/results/relu_results/trial"

test_dir = "/Users/sebastianlee/Dropbox/Documents/Work/Research/catastrophic/experiments/results/trial"
eR = process_logs.eventReader(test_dir)

# %%
val_dict = eR.get_values([("student_teacher_overlaps/0/values_1_0", True)])
# Out:
# WARNING:tensorflow:From /Users/sebastianlee/Envs/meta/lib/python3.7/site-packages/tensorflow/python/summary/summary_iterator.py:68: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`

# %%
plots = eR.generate_plots(val_dict, average=False, scale_axes=100000)

# %%
import numpy as np
np.mean(val_dict['independent']['generalisation_error/log']['teacher2']['seed_1'])
# Out:
# -8.626409567552239

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.0.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /Users/sebastianlee/Envs/cata/lib/python3.7/site-packages
# Requires: astor, keras-applications, opt-einsum, keras-preprocessing, numpy, protobuf, wheel, wrapt, grpcio, tensorboard, tensorflow-estimator, google-pasta, gast, six, absl-py, termcolor
# Required-by:

# %%
eR.teacher1_event_file_paths[0][0]
# Out:
# ['/Users/sebastianlee/Dropbox/Documents/Work/Research/catastrophic/experiments/results/trial/independent/seed25/events.out.tfevents.1573721394.Sebastians-MacBook-Pro.local']

# %%
process_logs._read_events_file("/Users/sebastianlee/Dropbox/Documents/Work/Research/catastrophic/experiments/results/trial/independent/seed25/teacher_1/events.out.tfevents.1573721394.Sebastians-MacBook-Pro.local", "generalisation_error/log")
# Out:
# [-1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
#  -1.1228669881820679,
# ...

# %%
test_path = "/Users/sebastianlee/Dropbox/Documents/Work/Research/catastrophic/experiments/results/relu_results/period_5000_seeds_5_independent"

# %%
import os

# %%
events_file1 = test_path + "/seed5/events.out.tfevents.1573721394.Sebastians-MacBook-Pro.local"
events_file2 = test_path + "/seed10/events.out.tfevents.1573721394.Sebastians-MacBook-Pro.local"

# %%
vals1 = process_logs.read_events_file(events_file1, attribute='student_teacher_overlaps/0/values_0_0')
vals2 = process_logs.read_events_file(events_file2, attribute='student_teacher_overlaps/0/values_0_0')
# Out:
# WARNING:tensorflow:From /Users/sebastianlee/Envs/meta/lib/python3.7/site-packages/tensorflow/python/summary/summary_iterator.py:68: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`

# %%
len(vals2)
# Out:
# 999

# %%
tf_f = tf.train.summary_iterator(events_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-81b9667f4635> in <module>
# ----> 1 tf_f = tf.train.summary_iterator(events_file)
#
# NameError: name 'tf' is not defined

# %%
import tensorflow as tf

# %%
tf_f

# %%
e = next(tf_f)

# %%
e

# %%
f1 = process_logs.make_plot(vals1)
f2 = process_logs.make_plot(vals2)

# %%
f1

# %%
f2

# %%
vall = [vals1, vals2]

# %%
import numpy as np
len(np.mean(vall, axis=0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8d2caf656dd2> in <module>
#       1 import numpy as np
# ----> 2 len(np.mean(vall, axis=0))
#
# NameError: name 'vall' is not defined

# %%
process_logs.make_plot([vals1, vals2])
